# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
# import data
parse_dates=['start_time', 'end_time']
df = pd.read_csv('./201902-fordgobike-tripdata.csv', parse_dates=parse_dates)

# %%
# create date col
df['trip_date']=df['end_time'].dt.date

# %%
# quick summary
df.tail()
# Out:
#         duration_sec              start_time                end_time  \
# 183407           480 2019-02-01 00:04:49.724 2019-02-01 00:12:50.034
# 183408           313 2019-02-01 00:05:34.744 2019-02-01 00:10:48.502
# 183409           141 2019-02-01 00:06:05.549 2019-02-01 00:08:27.220
# 183410           139 2019-02-01 00:05:34.360 2019-02-01 00:07:54.287
# 183411           271 2019-02-01 00:00:20.636 2019-02-01 00:04:52.058
#
#         start_station_id                                start_station_name  \
# 183407              27.0                           Beale St at Harrison St
# 183408              21.0  Montgomery St BART Station (Market St at 2nd St)
# 183409             278.0                            The Alameda at Bush St
# 183410             220.0                       San Pablo Ave at MLK Jr Way
# 183411              24.0                             Spear St at Folsom St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
# get trip counts per day
# df.groupby('trip_date').count()
df.groupby('trip_date').count()
# Out:
#             duration_sec  start_time  end_time  start_station_id  \
# trip_date
# 2019-02-01          6118        6118      6118              6114
# 2019-02-02          3241        3241      3241              3239
# 2019-02-03          2841        2841      2841              2840
# 2019-02-04          5487        5487      5487              5487
# 2019-02-05          8485        8485      8485              8483
# 2019-02-06          9056        9056      9056              9051
# 2019-02-07          9229        9229      9229              9225
# 2019-02-08          6362        6362      6362              6358
# 2019-02-09          2732        2732      2732              2723
# 2019-02-10          3953        3953      3953              3943
# 2019-02-11          8679        8679      8679              8662
# 2019-02-12          8481        8481      8481              8474
# 2019-02-13          3208        3208      3208              3206
# ...

# %%
# for a day 
# get count of bike trips per day 
# This will set the date column as an index 
isFebFirst=df['start_time']=='2019-02-01'
df = df.set_index(['start_time'])
df1=df.loc['2019-2-1':'2019-2-1']

# %%
# work with data from feb first
# sort data based on start_time
df1=df1.sort_values(by=['start_time'])
# Out:
#                          duration_sec                end_time  \
# start_time
# 2019-02-01 00:00:20.636           271 2019-02-01 00:04:52.058
# 2019-02-01 00:04:40.616           706 2019-02-01 00:16:27.080
# 2019-02-01 00:04:49.724           480 2019-02-01 00:12:50.034
# 2019-02-01 00:05:34.360           139 2019-02-01 00:07:54.287
# 2019-02-01 00:05:34.744           313 2019-02-01 00:10:48.502
#
#                          start_station_id  \
# start_time
# 2019-02-01 00:00:20.636              24.0
# 2019-02-01 00:04:40.616             138.0
# 2019-02-01 00:04:49.724              27.0
# 2019-02-01 00:05:34.360             220.0
# 2019-02-01 00:05:34.744              21.0
#
#                                                        start_station_name  \
# start_time
# 2019-02-01 00:00:20.636                             Spear St at Folsom St
# 2019-02-01 00:04:40.616                            Jersey St at Church St
# ...

# %%
# counts per bike id for a day 
df1bikeCount = df1.groupby('bike_id').count()

# %%
# Draw
